# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HCL\Desktop\churn analysis\customer churn.csv")
df.head(50)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ","0")
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "no"
        
df['SeniorCitizen'] = df["SeniorCitizen"].apply(conv)

# %% [markdown]
# #converted 0 and 1 values of senior citizen to yes/no to make it easier to understand

# %% [markdown]
# ## *1.Bar Chart*

# %%
ax = sns.countplot(x = 'Churn', data = df)

ax.bar_label(ax.containers[0])
plt.title("Count of customer by Churn")
plt.show()

# %% [raw]
# Q.What does the chart reveal about the customer churn distribution in the Telco dataset?
#
#  Answer:
# The chart shows that a significantly higher number of customers did not churn compared to those who did churn.
#
# 5174 customers stayed with the company (Churn = No)
#
# 1869 customers left the company (Churn = Yes)

# %% [markdown]
# ## *2.Pie Chart*

# %%
plt.figure(figsize = (3,4))
gb = df.groupby("Churn").agg({'Churn':"count"})
plt.pie(gb['Churn'], labels = gb.index, autopct = "%1.2f%%")
plt.title("Pertcentage of Churned Customeres", fontsize = 10)
plt.show()

# %% [markdown]
# Q. What percentage of customers have churned, and what does it imply for the business?
#
#  Answer:
# According to the pie chart, 26.54% of the customers have churned, while 73.46% have stayed with the company.
# This indicates that more than 1 out of every 4 customers is leaving the service, which is a significant churn rate for a telecom company.

# %% [markdown]
# #from the given pie chart we can conclude that 26.54% of our customers have churned out.#now lets explore the reason
# behind it

# %% [markdown]
# ## *3.Countplot*

# %%
plt.figure(figsize = (3,3))
sns.countplot(x = "gender", data = df, hue = "Churn")
plt.title("Churn by Gender")
plt.show()

# %% [raw]
# Q. Does customer churn significantly differ between male and female customers?
#  Answer:
# The chart shows that churn is almost equally distributed among both male and female customers.
#
# Both genders have nearly the same number of customers who did not churn.

# %% [markdown]
# ## *4.Bar Chart*

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "SeniorCitizen", data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of Customers by SeniorCitizen")
plt.show()

# %% [raw]
# Q. What does the distribution of senior citizens in the customer base reveal?
# Answer:
# The bar chart shows that out of all customers:
# * 5901 are not senior citizens (SeniorCitizen = 0)
# * Only 1142 are senior citizens (SeniorCitizen = 1)

# %% [markdown]
# ## *5.Stacked Bar Chart*

# %%
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'])

# Step 2: Convert to row-wise percentages
ct_percent = ct.div(ct.sum(axis=1), axis=0) * 100

# Step 3: Plot the stacked bar chart
ax = ct_percent.plot(kind='bar', stacked=True, figsize=(4,4), colormap='Accent')

# Step 4: Add % labels inside each bar
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', label_type='center', fontsize=8)

# Final touches
plt.title("Churn by SeniorCitizen (as %)")
plt.xlabel("Senior Citizen (0 = No, 1 = Yes)")
plt.ylabel("Percentage")
plt.legend(title="Churn")
plt.tight_layout()
plt.show()

# %% [raw]
# Q. How does the churn rate differ between senior citizens and non-senior citizens?
#
#  Answer:
# The chart shows a clear difference in churn behavior between the two age groups:
# Senior Citizens (1) have a much higher churn rate of 41.7%
# Non-Senior Citizens (0) have a churn rate of only 23.6%

# %% [markdown]
# #comparative a greater Percentage of people in senior citizen category have churned

# %% [markdown]
# ## *6.Histogram*

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "tenure", data = df, bins = 72, hue = "Churn")
plt.show()

# %% [markdown]
# Q. How does a customer's tenure (length of stay) relate to their likelihood of churning?
#
#  Answer:
# The histogram reveals a strong relationship between tenure and churn:
# Customers with very low tenure (0–10 months) show the highest churn rate.
# As tenure increases, the number of churned customers decreases steadily.
# Customers with long tenure (above 60 months) rarely churn and are mostly retained.

# %% [markdown]
# #people who have used our services for a long time have stayed and people who have used our services #1 or 2
# month have churned

# %% [markdown]
# ## *7.Bar Chart*

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "Contract", data = df, hue = "Churn")
ax.bar_label(ax.containers[0])
plt.title("Count of Customers by Contract")
plt.show()

# %% [raw]
# Q. How does the type of contract impact customer churn?
#
#  Answer:
# The chart clearly shows that contract type has a strong impact on churn behavior:
# Customers with month-to-month contracts have the highest churn, with a large number choosing to leave.
# Customers on one-year and especially two-year contracts show much lower churn rates.

# %%
#people who have month to month contract are likely to churn then from those who have 1 or 2 years or contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %% [markdown]
# ## *8.Bar Chart*

# %%
# List of columns
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Number of columns for the subplot grid
n_cols = 3
n_rows = (len(cols) + n_cols - 1) // n_cols  # Calculate number of rows needed

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4))

# Flatten the axes array
axes = axes.flatten()

# Iterate over columns and plot count plots
for i, col in enumerate(cols):
    sns.countplot(x=col, data=df, ax=axes[i], hue=df["Churn"])
    axes[i].set_title(f'Count Plot of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

# Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # the majority of customers who do not churn tend to have services like phoneservice (particular DSL), and onlinesecurity enabled. for services like
# onlinebackup, techsupport, and streamingTV, churn rates are noticeable higher when these services are not used pr are unavailable.

# %% [markdown]
# ## *9.Countplot*

# %%
plt.figure(figsize = (6,4))
ax = sns.countplot(x = "PaymentMethod", data = df, hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Churned Customers by Payment Method")
plt.xticks(rotation = 45)
plt.show()

# %% [raw]
# Q. Which payment method is associated with the highest customer churn?
#
#  Answer:
# Electronic check has the highest number of churned customers (1071 out of 2365 total users).
# Other payment methods like Mailed check, Bank transfer (automatic), and Credit card (automatic) have much lower churn numbers (~250–300).

# %%
#customer is likely to churn when he is using electronic check as a payment method.

# %% [markdown]
# ## *10.Line chart*

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
churn_rate = [5, 6, 4.5, 7, 6.5]

plt.plot(months, churn_rate, marker='o')
plt.title("Monthly Churn Rate")
plt.xlabel("Month")
plt.ylabel("Churn Rate (%)")
plt.grid(True)
plt.show()

# %% [raw]
# Q. Which month had the highest customer churn rate, and how did the churn trend change over the 5-month period?
#
#  Answer:
# The month with the highest churn rate was April, with a 7% churn rate.
# The churn rate across the months was:
# January – 5%
# February – 6%
# March – 4.5% (lowest)
# April – 7% (highest)
# May – 6.5%

# %% [markdown]
# ## *11.Scatter Plot*

# %%
sns.scatterplot(x='MonthlyCharges', y='TotalCharges', hue='Churn', data=df)
plt.title("Monthly vs Total Charges by Churn Status")
plt.show()

# %% [raw]
# Q. How does the customer churn rate vary from January to May, and what insights can be drawn from the trend?
#
# Answer:
# From the line graph:
# January: 5%
# February: 6%
# March: 4.5% (lowest churn)
# April: 7% (highest churn )
# May: 6.5%

# %% [markdown]
# ## *12.Countplot*

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='PaperlessBilling', hue='Churn', palette='Set2')
plt.title("Churn by Billing Type (Paper vs Electronic)")
plt.xlabel("Paperless Billing (No = Paper Billing)")
plt.ylabel("Number of Customers")
plt.legend(title='Churn')
plt.show()

# %%
Q. What does the countplot indicate about customer churn behavior with respect to billing type (Paper vs Paperless)?

 Answer:
The countplot compares the number of churned and retained customers between those who use paperless billing and those who do not.
 Observations:
A higher number of customers who use paperless billing (Yes) have churned compared to those who do not use paperless billing.
Customers with paper billing (No) have a lower churn rate, with most of them staying with the service.

# %% [markdown]
# ## *Conclusion*

# %% [raw]
# The Telco customer churn analysis has provided valuable insights into the factors influencing customer retention and churn behavior.
# Key findings from the data are as follows:
#
# 1. Tenure and Contract Type are Strong Indicators of Churn
#
#     Customers with shorter tenure (new customers) are more likely to churn.
#
#      Customers on month-to-month contracts have the highest churn rates compared to those with 1-year or 2-year contracts.
#
# 2. Services Impact Churn
#
#     Customers without tech support, online security, or backup services tend to churn more often.
#
#      Lack of value-added services correlates with dissatisfaction and churn.
#
# 3. Billing and Charges Matter
#
#     Higher monthly charges are associated with increased churn, especially among short-tenure customers.
#
#     Customers with electronic billing tend to churn more than those with mailed billing.
#
# 4. Demographics and Churn
#
#    Senior citizens and single customers (no partners/dependents) show a slightly higher churn rate.
#
#    Gender does not have a significant impact on churn behavior.
#
# 5. Customer Engagement Drives Retention
#
# Long-term contracts, bundled services, and consistent service quality play a crucial role in retaining customers
